# %%
# !python --version
# Out:
# Python 3.8.6

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas
from tensorflow.keras.models import Sequential
import tensorflow as tf
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import optimizers
from keras.callbacks import EarlyStopping
from keras.layers.normalization import BatchNormalization
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from keras.callbacks import EarlyStopping
from keras.layers.normalization import BatchNormalization
from keras.layers import InputLayer
import pickle

# %%
csv = './openpowerlifting-2020-09-06.csv'
df = pandas.read_csv(csv,index_col=0,low_memory=False)
df['Sex'] = df['Sex'].map({'M': 1, 'F': 0, 'Mx': -1})
df['Equipment'] = df['Equipment'].map({'Single-ply':0, 'Raw':1, 'Wraps':2, 'Unlimited':3, 'Multi-ply':4})
data = df[['Sex','BodyweightKg', 'Best3SquatKg', 'Best3DeadliftKg','Age','Equipment', 'Best3BenchKg']].dropna(how='any')

# %%
sc = MinMaxScaler()
data_std = sc.fit_transform(data)
data
# Out:
# array([[1.        , 0.27892064, 0.62595599, ..., 0.28795812, 0.5       ,
#         0.60893617],
#        [1.        , 0.27892064, 0.61486553, ..., 0.34031414, 0.5       ,
#         0.57584195],
#        [1.        , 0.39727148, 0.71689976, ..., 0.2513089 , 0.5       ,
#         0.63925836],
#        ...,
#        [1.        , 0.36499397, 0.67481663, ..., 0.22513089, 0.25      ,
#         0.64741641],
#        [1.        , 0.32410914, 0.60146699, ..., 0.19371728, 0.25      ,
#         0.59878419],
#        [1.        , 0.27461697, 0.62591687, ..., 0.19371728, 0.25      ,
#         0.5775076 ]])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data_std[:,:-1], data_std[:,-1], test_size=0.2)
X_train, X_validation, Y_train, Y_validation = train_test_split(X_train, Y_train, test_size=0.2)

# %%
def r_square(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return (1 - SS_res/(SS_tot + K.epsilon()))

# %%
n_features = 6
n_hidden   = 4
model = Sequential()
model.add(InputLayer(input_shape=(n_features,)))
model.add(Dense(1))
model.add(Activation('linear'))
# optimizer = optimizers.Adam(learning_rate=0.001, beta_1 = 0.9, beta_2=0.999, amsgrad=True)
optimizer = optimizers.SGD(learning_rate=0.1)
model.compile(optimizer=optimizer,
              loss='mse', metrics=['mae', r_square])
log = model.fit(X_train, Y_train, epochs=20, batch_size=64, verbose=1,
         validation_data=(X_validation, Y_validation))
Y_pred = model.predict(X_test)
# Out:
# Epoch 1/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 0.0024 - mae: 0.0304 - r_square: 0.3895 - val_loss: 7.1448e-04 - val_mae: 0.0183 - val_r_square: 0.8216
# Epoch 2/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.9024e-04 - mae: 0.0176 - r_square: 0.8298 - val_loss: 7.0800e-04 - val_mae: 0.0177 - val_r_square: 0.8243
# Epoch 3/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 6.9454e-04 - mae: 0.0175 - r_square: 0.8298 - val_loss: 6.8167e-04 - val_mae: 0.0176 - val_r_square: 0.8306
# Epoch 4/20
# 6812/6812 [==============================] - 8s 1ms/step - loss: 6.9223e-04 - mae: 0.0176 - r_square: 0.8301 - val_loss: 6.7830e-04 - val_mae: 0.0175 - val_r_square: 0.8317
# Epoch 5/20
# 6812/6812 [==============================] - 8s 1ms/step - loss: 6.9034e-04 - mae: 0.0175 - r_square: 0.8310 - val_loss: 6.7906e-04 - val_mae: 0.0173 - val_r_square: 0.8317
# Epoch 6/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.9620e-04 - mae: 0.0176 - r_square: 0.8296 - val_loss: 6.7712e-04 - val_mae: 0.0174 - val_r_square: 0.8321
# Epoch 7/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 6.8899e-04 - mae: 0.0175 - r_square: 0.8310 - val_loss: 6.7836e-04 - val_mae: 0.0175 - val_r_square: 0.8317
# Epoch 8/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.0300e-04 - mae: 0.0176 - r_square: 0.8286 - val_loss: 6.7724e-04 - val_mae: 0.0174 - val_r_square: 0.8321
# Epoch 9/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.0029e-04 - mae: 0.0176 - r_square: 0.8287 - val_loss: 6.8210e-04 - val_mae: 0.0176 - val_r_square: 0.8306
# Epoch 10/20
# 6812/6812 [==============================] - 8s 1ms/step - loss: 6.9532e-04 - mae: 0.0175 - r_square: 0.8295 - val_loss: 6.8323e-04 - val_mae: 0.0176 - val_r_square: 0.8303
# Epoch 11/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.9856e-04 - mae: 0.0176 - r_square: 0.8295 - val_loss: 6.7924e-04 - val_mae: 0.0175 - val_r_square: 0.8314
# Epoch 12/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 7.0025e-04 - mae: 0.0176 - r_square: 0.8289 - val_loss: 6.7768e-04 - val_mae: 0.0174 - val_r_square: 0.8319
# Epoch 13/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.9572e-04 - mae: 0.0175 - r_square: 0.8296 - val_loss: 6.7743e-04 - val_mae: 0.0173 - val_r_square: 0.8320
# Epoch 14/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 6.9690e-04 - mae: 0.0176 - r_square: 0.8290 - val_loss: 6.7712e-04 - val_mae: 0.0174 - val_r_square: 0.8321
# Epoch 15/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 6.9499e-04 - mae: 0.0175 - r_square: 0.8301 - val_loss: 6.7757e-04 - val_mae: 0.0173 - val_r_square: 0.8320
# Epoch 16/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.9930e-04 - mae: 0.0176 - r_square: 0.8291 - val_loss: 6.8291e-04 - val_mae: 0.0176 - val_r_square: 0.8304
# Epoch 17/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.9315e-04 - mae: 0.0176 - r_square: 0.8293 - val_loss: 6.8573e-04 - val_mae: 0.0174 - val_r_square: 0.8301
# Epoch 18/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.9274e-04 - mae: 0.0175 - r_square: 0.8295 - val_loss: 7.2636e-04 - val_mae: 0.0180 - val_r_square: 0.8198
# Epoch 19/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.9111e-04 - mae: 0.0175 - r_square: 0.8305 - val_loss: 6.7721e-04 - val_mae: 0.0174 - val_r_square: 0.8320
# Epoch 20/20
# 6812/6812 [==============================] - 8s 1ms/step - loss: 7.0348e-04 - mae: 0.0176 - r_square: 0.8283 - val_loss: 7.0021e-04 - val_mae: 0.0176 - val_r_square: 0.8265

# %%
plt.plot(log.history['val_r_square'])
plt.plot(log.history['r_square'])
plt.title('model R^2')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# plot training curve for rmse
plt.plot(log.history['mae'])
plt.plot(log.history['val_mae'])
plt.title('mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
n_features = 6
n_hidden   = 4
model = Sequential()
model.add(InputLayer(input_shape=(n_features,)))
model.add(Dense(n_hidden, activation='sigmoid'))
model.add(Dense(1))
model.add(Activation('linear'))
# optimizer = optimizers.Adam(learning_rate=0.001, beta_1 = 0.9, beta_2=0.999, amsgrad=True)
optimizer = optimizers.SGD(learning_rate=0.1)
model.compile(optimizer=optimizer,
              loss='mse', metrics=['mae', r_square])
log = model.fit(X_train, Y_train, epochs=20, batch_size=64, verbose=1,
         validation_data=(X_validation, Y_validation))
Y_pred = model.predict(X_test)
Y_pred = model.predict(X_test)
plt.plot(log.history['val_r_square'])
plt.plot(log.history['r_square'])
plt.title('model R^2')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# plot training curve for rmse
plt.plot(log.history['mae'])
plt.plot(log.history['val_mae'])
plt.title('mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 0.0028 - mae: 0.0399 - r_square: 0.3114 - val_loss: 9.7836e-04 - val_mae: 0.0222 - val_r_square: 0.7576
# Epoch 2/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 9.3499e-04 - mae: 0.0216 - r_square: 0.7692 - val_loss: 8.2168e-04 - val_mae: 0.0201 - val_r_square: 0.7965
# Epoch 3/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 8.2486e-04 - mae: 0.0198 - r_square: 0.7983 - val_loss: 7.7995e-04 - val_mae: 0.0196 - val_r_square: 0.8062
# Epoch 4/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 7.5738e-04 - mae: 0.0188 - r_square: 0.8149 - val_loss: 7.2652e-04 - val_mae: 0.0182 - val_r_square: 0.8205
# Epoch 5/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 7.2988e-04 - mae: 0.0183 - r_square: 0.8216 - val_loss: 7.0215e-04 - val_mae: 0.0179 - val_r_square: 0.8263
# Epoch 6/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.1232e-04 - mae: 0.0180 - r_square: 0.8255 - val_loss: 6.9631e-04 - val_mae: 0.0177 - val_r_square: 0.8278
# Epoch 7/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.1367e-04 - mae: 0.0178 - r_square: 0.8263 - val_loss: 6.9147e-04 - val_mae: 0.0176 - val_r_square: 0.8289
# Epoch 8/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.0318e-04 - mae: 0.0178 - r_square: 0.8279 - val_loss: 6.8927e-04 - val_mae: 0.0175 - val_r_square: 0.8293
# Epoch 9/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.1756e-04 - mae: 0.0177 - r_square: 0.8255 - val_loss: 7.0482e-04 - val_mae: 0.0181 - val_r_square: 0.8248
# Epoch 10/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.0805e-04 - mae: 0.0177 - r_square: 0.8265 - val_loss: 6.9969e-04 - val_mae: 0.0176 - val_r_square: 0.8268
# Epoch 11/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.9324e-04 - mae: 0.0176 - r_square: 0.8291 - val_loss: 6.8697e-04 - val_mae: 0.0175 - val_r_square: 0.8298
# Epoch 12/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.0269e-04 - mae: 0.0176 - r_square: 0.8287 - val_loss: 7.2593e-04 - val_mae: 0.0187 - val_r_square: 0.8191
# Epoch 13/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 6.9615e-04 - mae: 0.0176 - r_square: 0.8281 - val_loss: 6.9317e-04 - val_mae: 0.0178 - val_r_square: 0.8279
# Epoch 14/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.0527e-04 - mae: 0.0176 - r_square: 0.8270 - val_loss: 7.0592e-04 - val_mae: 0.0181 - val_r_square: 0.8244
# Epoch 15/20
# 6812/6812 [==============================] - 8s 1ms/step - loss: 6.8644e-04 - mae: 0.0176 - r_square: 0.8310 - val_loss: 6.8837e-04 - val_mae: 0.0174 - val_r_square: 0.8295
# Epoch 16/20
# 6812/6812 [==============================] - 8s 1ms/step - loss: 7.1105e-04 - mae: 0.0177 - r_square: 0.8262 - val_loss: 6.8929e-04 - val_mae: 0.0177 - val_r_square: 0.8289
# Epoch 17/20
# 6812/6812 [==============================] - 8s 1ms/step - loss: 7.1065e-04 - mae: 0.0176 - r_square: 0.8275 - val_loss: 6.8841e-04 - val_mae: 0.0174 - val_r_square: 0.8295
# Epoch 18/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.0023e-04 - mae: 0.0176 - r_square: 0.8284 - val_loss: 6.8686e-04 - val_mae: 0.0174 - val_r_square: 0.8298
# Epoch 19/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.0940e-04 - mae: 0.0176 - r_square: 0.8275 - val_loss: 6.8738e-04 - val_mae: 0.0176 - val_r_square: 0.8294
# Epoch 20/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.1500e-04 - mae: 0.0176 - r_square: 0.8266 - val_loss: 6.8429e-04 - val_mae: 0.0175 - val_r_square: 0.8304

# %%
n_features = 6
n_hidden   = 4
model = Sequential()
model.add(InputLayer(input_shape=(n_features,)))
model.add(Dense(n_hidden, activation='tanh'))
model.add(Dense(1))
model.add(Activation('linear'))
# optimizer = optimizers.Adam(learning_rate=0.001, beta_1 = 0.9, beta_2=0.999, amsgrad=True)
optimizer = optimizers.SGD(learning_rate=0.1)
model.compile(optimizer=optimizer,
              loss='mse', metrics=['mae', r_square])
log = model.fit(X_train, Y_train, epochs=20, batch_size=64, verbose=1,
         validation_data=(X_validation, Y_validation))
Y_pred = model.predict(X_test)
Y_pred = model.predict(X_test)
plt.plot(log.history['val_r_square'])
plt.plot(log.history['r_square'])
plt.title('model R^2')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# plot training curve for rmse
plt.plot(log.history['mae'])
plt.plot(log.history['val_mae'])
plt.title('mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 0.0049 - mae: 0.0351 - r_square: -0.2143 - val_loss: 7.2133e-04 - val_mae: 0.0180 - val_r_square: 0.8213
# Epoch 2/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 7.3219e-04 - mae: 0.0181 - r_square: 0.8208 - val_loss: 7.2508e-04 - val_mae: 0.0180 - val_r_square: 0.8204
# Epoch 3/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.1626e-04 - mae: 0.0179 - r_square: 0.8255 - val_loss: 7.3647e-04 - val_mae: 0.0188 - val_r_square: 0.8164
# Epoch 4/20
# 6812/6812 [==============================] - 12s 2ms/step - loss: 7.2246e-04 - mae: 0.0178 - r_square: 0.8232 - val_loss: 6.9396e-04 - val_mae: 0.0177 - val_r_square: 0.8279
# Epoch 5/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 7.0160e-04 - mae: 0.0177 - r_square: 0.8281 - val_loss: 7.1188e-04 - val_mae: 0.0183 - val_r_square: 0.8229
# Epoch 6/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.0571e-04 - mae: 0.0177 - r_square: 0.8288 - val_loss: 6.9866e-04 - val_mae: 0.0180 - val_r_square: 0.8264
# Epoch 7/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.9384e-04 - mae: 0.0176 - r_square: 0.8307 - val_loss: 7.1072e-04 - val_mae: 0.0178 - val_r_square: 0.8241
# Epoch 8/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 7.2057e-04 - mae: 0.0177 - r_square: 0.8252 - val_loss: 6.8076e-04 - val_mae: 0.0175 - val_r_square: 0.8313
# Epoch 9/20
# 6812/6812 [==============================] - 11s 2ms/step - loss: 6.9011e-04 - mae: 0.0176 - r_square: 0.8303 - val_loss: 6.7879e-04 - val_mae: 0.0174 - val_r_square: 0.8320
# Epoch 10/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 6.9194e-04 - mae: 0.0176 - r_square: 0.8299 - val_loss: 6.7505e-04 - val_mae: 0.0174 - val_r_square: 0.8328
# Epoch 11/20
# 6812/6812 [==============================] - 12s 2ms/step - loss: 6.8839e-04 - mae: 0.0175 - r_square: 0.8317 - val_loss: 6.7317e-04 - val_mae: 0.0174 - val_r_square: 0.8333
# Epoch 12/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 6.9685e-04 - mae: 0.0175 - r_square: 0.8303 - val_loss: 6.9035e-04 - val_mae: 0.0180 - val_r_square: 0.8285
# Epoch 13/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 6.8087e-04 - mae: 0.0175 - r_square: 0.8327 - val_loss: 6.7966e-04 - val_mae: 0.0174 - val_r_square: 0.8319
# Epoch 14/20
# 6812/6812 [==============================] - 10s 1ms/step - loss: 6.8469e-04 - mae: 0.0175 - r_square: 0.8316 - val_loss: 6.9697e-04 - val_mae: 0.0177 - val_r_square: 0.8275
# Epoch 15/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.8713e-04 - mae: 0.0175 - r_square: 0.8311 - val_loss: 7.2390e-04 - val_mae: 0.0188 - val_r_square: 0.8194
# Epoch 16/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.8322e-04 - mae: 0.0174 - r_square: 0.8334 - val_loss: 6.6465e-04 - val_mae: 0.0173 - val_r_square: 0.8355
# Epoch 17/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.8205e-04 - mae: 0.0175 - r_square: 0.8327 - val_loss: 6.7638e-04 - val_mae: 0.0177 - val_r_square: 0.8321
# Epoch 18/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.7943e-04 - mae: 0.0175 - r_square: 0.8336 - val_loss: 6.6566e-04 - val_mae: 0.0174 - val_r_square: 0.8351
# Epoch 19/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.7520e-04 - mae: 0.0174 - r_square: 0.8341 - val_loss: 6.6090e-04 - val_mae: 0.0173 - val_r_square: 0.8364
# Epoch 20/20
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.8220e-04 - mae: 0.0174 - r_square: 0.8337 - val_loss: 6.7793e-04 - val_mae: 0.0178 - val_r_square: 0.8316

# %%
n_features = 6
n_hidden   = 4
model = Sequential()
model.add(InputLayer(input_shape=(n_features,)))
model.add(Dense(n_hidden, activation='tanh'))
model.add(Dense(n_hidden, activation='tanh'))
model.add(Dense(n_hidden, activation='tanh'))
model.add(Dense(1))
model.add(Activation('linear'))
# optimizer = optimizers.Adam(learning_rate=0.001, beta_1 = 0.9, beta_2=0.999, amsgrad=True)
optimizer = optimizers.SGD(learning_rate=0.1)
model.compile(optimizer=optimizer,
              loss='mse', metrics=['mae', r_square])
log = model.fit(X_train, Y_train, epochs=30, batch_size=64, verbose=1,
         validation_data=(X_validation, Y_validation))
Y_pred = model.predict(X_test)
Y_pred = model.predict(X_test)
plt.plot(log.history['val_r_square'])
plt.plot(log.history['r_square'])
plt.title('model R^2')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# plot training curve for rmse
plt.plot(log.history['mae'])
plt.plot(log.history['val_mae'])
plt.title('mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/30
# 6812/6812 [==============================] - 11s 2ms/step - loss:
30
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.8343e-04 - mae: 0.0175 - r_square: 0.8330 - val_loss: 7.4120e-04 - val_mae: 0.0185 - val_r_square: 0.8159
# Epoch 19/30
# 6812/6812 [==============================] - 11s 2ms/step - loss: 6.7539e-04 - mae: 0.0175 - r_square: 0.8332 - val_loss: 6.5624e-04 - val_mae: 0.0172 - val_r_square: 0.8374
# Epoch 20/30
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.8407e-04 - mae: 0.0175 - r_square: 0.8318 - val_loss: 7.0710e-04 - val_mae: 0.0186 - val_r_square: 0.8237
# Epoch 21/30
# 6812/6812 [==============================] - 10s 1ms/step - loss: 6.6773e-04 - mae: 0.0175 - r_square: 0.8357 - val_loss: 6.8358e-04 - val_mae: 0.0181 - val_r_square: 0.8300
# Epoch 22/30
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.7544e-04 - mae: 0.0174 - r_square: 0.8341 - val_loss: 6.9784e-04 - val_mae: 0.0184 - val_r_square: 0.8260
# Epoch 23/30
# 6812/6812 [==============================] - 11s 2ms/step - loss: 6.7927e-04 - mae: 0.0174 - r_square: 0.8338 - val_loss: 6.7028e-04 - val_mae: 0.0177 - val_r_square: 0.8334
# Epoch 24/30
# 6812/6812 [==============================] - 10s 1ms/step - loss: 6.9496e-04 - mae: 0.0175 - r_square: 0.8313 - val_loss: 6.5520e-04 - val_mae: 0.0171 - val_r_square: 0.8377
# Epoch 25/30
# 6812/6812 [==============================] - 10s 1ms/step - loss: 6.7815e-04 - mae: 0.0174 - r_square: 0.8334 - val_loss: 6.5193e-04 - val_mae: 0.0172 - val_r_square: 0.8384
# Epoch 26/30
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.7922e-04 - mae: 0.0174 - r_square: 0.8341 - val_loss: 6.5224e-04 - val_mae: 0.0171 - val_r_square: 0.8385
# Epoch 27/30
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.6628e-04 - mae: 0.0174 - r_square: 0.8361 - val_loss: 7.1666e-04 - val_mae: 0.0181 - val_r_square: 0.8220
# Epoch 28/30
# 6812/6812 [==============================] - 10s 1ms/step - loss: 6.8129e-04 - mae: 0.0174 - r_square: 0.8337 - val_loss: 6.6702e-04 - val_mae: 0.0172 - val_r_square: 0.8348
# Epoch 29/30
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.6771e-04 - mae: 0.0173 - r_square: 0.8367 - val_loss: 6.5132e-04 - val_mae: 0.0170 - val_r_square: 0.8387
# Epoch 30/30
# 6812/6812 [==============================] - 9s 1ms/step - loss: 6.6398e-04 - mae: 0.0174 - r_square: 0.8373 - val_loss: 6.4989e-04 - val_mae: 0.0170 - val_r_square: 0.8391

# %%
n_features = 6
n_hidden   = 4
model = Sequential()
model.add(InputLayer(input_shape=(n_features,)))
model.add(Dense(n_hidden, activation='tanh'))
model.add(Dense(n_hidden, activation='tanh'))
model.add(Dense(n_hidden, activation='tanh'))
model.add(Dense(n_hidden, activation='tanh'))
model.add(Dense(1))
model.add(Activation('linear'))
optimizer = optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss='mse', metrics=['mae', r_square])
log = model.fit(X_train, Y_train, epochs=30, batch_size=64, verbose=1,
         validation_data=(X_validation, Y_validation))
Y_pred = model.predict(X_test)
Y_pred = model.predict(X_test)
plt.plot(log.history['val_r_square'])
plt.plot(log.history['r_square'])
plt.title('model R^2')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# plot training curve for rmse
plt.plot(log.history['mae'])
plt.plot(log.history['val_mae'])
plt.title('mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1